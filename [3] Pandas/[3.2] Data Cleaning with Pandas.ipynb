# %% [markdown]
# # Survey Data Cleaning and Preprocessing
#
# In this notebook, we will learn how to clean and preprocess survey data using the Pandas library. Data cleaning is an essential first step in data analysis because real-world data is often messy. Cleaning ensures that our dataset is consistent, accurate, and ready for further analysis.

# %%
import pandas as pd
import numpy as np

# Load data from CSV
df = pd.read_csv("./Data/Stress_Dataset.csv")
df.head()
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Have you been getting headaches more often than usual?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    Do you get irritated easily?  \
# 0                             1
# 1                             1
# 2                             4
# 3                             4
# 4                             4
#
#    Do you have trouble concentrating on your academic tasks?  ...  \
# 0                                                  2          ...
# 1                                                  4          ...
# 2                                                  2          ...
# 3                                                  3          ...
# 4                                                  4          ...
#
#    Are you facing any difficulties with your professors or instructors?  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    Is your working environment unpleasant or stressful?  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                  4
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    Is your hostel or home environment causing you difficulties?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you lack confidence in your academic performance?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  2
# 4                                                  2
#
#    Do you lack confidence in your choice of academic subjects?  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    Academic and extracurricular activities conflicting for you?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                 1                             2
# 1                                 4                             2
# 2                                 2                             1
# 3                                 5                             3
# 4                                 2                             2
#
#    Which type of stress do you primarily experience?
# 0  Eustress (Positive Stress) - Stress that motiv...
# 1  Eustress (Positive Stress) - Stress that motiv...
# 2  Eustress (Positive Stress) - Stress that motiv...
# 3  Eustress (Positive Stress) - Stress that motiv...
# 4  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 1. Exploring the Dataset
#
# Before cleaning, it is important to explore the dataset. This helps us understand the structure, data types, and possible issues such as missing values or duplicated columns.

# %%
# Display basic information about the dataset
df.info()

# Display summary statistics
df.describe(include="all").T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 26 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Gender                                                                843 non-null    int64
#  1   Age                                                                   843 non-null    int64
#  2   Have you recently experienced stress in your life?                    843 non-null    int64
#  3   Have you noticed a rapid heartbeat or palpitations?                   843 non-null    int64
#  4   Have you been dealing with anxiety or tension recently?               843 non-null    int64
#  5   Do you face any sleep problems or difficulties falling asleep?        843 non-null    int64
#  6   Have you been dealing with anxiety or tension recently?.1             843 non-null    int64
#  7   Have you been getting headaches more often than usual?                843 non-null    int64
#  8   Do you get irritated easily?                                          843 non-null    int64
#  9   Do you have trouble concentrating on your academic tasks?             843 non-null    int64
#  10  Have you been feeling sadness or low mood?                            843 non-null    int64
#  11  Have you been experiencing any illness or health issues?              843 non-null    int64
#  12  Do you often feel lonely or isolated?                                 843 non-null    int64
#  13  Do you feel overwhelmed with your academic workload?                  843 non-null    int64
#  14  Are you in competition with your peers, and does it affect you?       843 non-null    int64
#  15  Do you find that your relationship often causes you stress?           843 non-null    int64
#  16  Are you facing any difficulties with your professors or instructors?  843 non-null    int64
#  17  Is your working environment unpleasant or stressful?                  843 non-null    int64
#  18  Do you struggle to find time for relaxation and leisure activities?   843 non-null    int64
#  19  Is your hostel or home environment causing you difficulties?          843 non-null    int64
#  20  Do you lack confidence in your academic performance?                  843 non-null    int64
#  21  Do you lack confidence in your choice of academic subjects?           843 non-null    int64
#  22  Academic and extracurricular activities conflicting for you?          843 non-null    int64
#  23  Do you attend classes regularly?                                      843 non-null    int64
#  24  Have you gained/lost weight?                                          843 non-null    int64
#  25  Which type of stress do you primarily experience?                     843 non-null    object
# dtypes: int64(25), object(1)
# memory usage: 171.4+ KB
#                                                     count unique  \
# Gender                                              843.0    NaN
# Age                                                 843.0    NaN
# Have you recently experienced stress in your life?  843.0    NaN
# Have you noticed a rapid heartbeat or palpitati...  843.0    NaN
# Have you been dealing with anxiety or tension r...  843.0    NaN
# Do you face any sleep problems or difficulties ...  843.0    NaN
# Have you been dealing with anxiety or tension r...  843.0    NaN
# Have you been getting headaches more often than...  843.0    NaN
# Do you get irritated easily?                        843.0    NaN
# Do you have trouble concentrating on your acade...  843.0    NaN
# Have you been feeling sadness or low mood?          843.0    NaN
# Have you been experiencing any illness or healt...  843.0    NaN
# Do you often feel lonely or isolated?               843.0    NaN
# Do you feel overwhelmed with your academic work...  843.0    NaN
# Are you in competition with your peers, and doe...  843.0    NaN
# Do you find that your relationship often causes...  843.0    NaN
# Are you facing any difficulties with your profe...  843.0    NaN
# Is your working environment unpleasant or stres...  843.0    NaN
# Do you struggle to find time for relaxation and...  843.0    NaN
# Is your hostel or home environment causing you ...  843.0    NaN
# Do you lack confidence in your academic perform...  843.0    NaN
# Do you lack confidence in your choice of academ...  843.0    NaN
# Academic and extracurricular activities conflic...  843.0    NaN
# Do you attend classes regularly?                    843.0    NaN
# Have you gained/lost weight?                        843.0    NaN
# Which type of stress do you primarily experience?     843      3
#
#                                                                                                   top  \
# Gender                                                                                            NaN
# Age                                                                                               NaN
# Have you recently experienced stress in your life?                                                NaN
# Have you noticed a rapid heartbeat or palpitati...                                                NaN
# Have you been dealing with anxiety or tension r...                                                NaN
# Do you face any sleep problems or difficulties ...                                                NaN
# Have you been dealing with anxiety or tension r...                                                NaN
# Have you been getting headaches more often than...                                                NaN
# Do you get irritated easily?                                                                      NaN
# Do you have trouble concentrating on your acade...                                                NaN
# Have you been feeling sadness or low mood?                                                        NaN
# Have you been experiencing any illness or healt...                                                NaN
# Do you often feel lonely or isolated?                                                             NaN
# Do you feel overwhelmed with your academic work...                                                NaN
# Are you in competition with your peers, and doe...                                                NaN
# Do you find that your relationship often causes...                                                NaN
# Are you facing any difficulties with your profe...                                                NaN
# Is your working environment unpleasant or stres...                                                NaN
# Do you struggle to find time for relaxation and...                                                NaN
# Is your hostel or home environment causing you ...                                                NaN
# Do you lack confidence in your academic perform...                                                NaN
# Do you lack confidence in your choice of academ...                                                NaN
# Academic and extracurricular activities conflic...                                                NaN
# Do you attend classes regularly?                                                                  NaN
# Have you gained/lost weight?                                                                      NaN
# Which type of stress do you primarily experience?   Eustress (Positive Stress) - Stress that motiv...
#
#                                                    freq       mean       std  \
# Gender                                              NaN   0.349941  0.477234
# Age                                                 NaN  20.071174  5.429502
# Have you recently experienced stress in your life?  NaN   2.997628  1.134639
# Have you noticed a rapid heartbeat or palpitati...  NaN   2.755635   1.11865
# Have you been dealing with anxiety or tension r...  NaN   2.543298   1.20133
# Do you face any sleep problems or difficulties ...  NaN   2.786477  1.266959
# Have you been dealing with anxiety or tension r...  NaN   2.663108  1.266376
# Have you been getting headaches more often than...  NaN   2.628707  1.266593
# Do you get irritated easily?                        NaN   2.702254  1.314213
# Do you have trouble concentrating on your acade...  NaN   2.699881  1.313673
# Have you been feeling sadness or low mood?          NaN   2.584816   1.23329
# Have you been experiencing any illness or healt...  NaN   2.549229  1.254307
# Do you often feel lonely or isolated?               NaN   2.497034  1.258106
# Do you feel overwhelmed with your academic work...  NaN   2.504152  1.250527
# Are you in competition with your peers, and doe...  NaN   2.485172  1.217726
# Do you find that your relationship often causes...  NaN   2.514828  1.241869
# Are you facing any difficulties with your profe...  NaN   2.447212  1.195995
# Is your working environment unpleasant or stres...  NaN   2.488731  1.196116
# Do you struggle to find time for relaxation and...  NaN     2.5172  1.247563
# Is your hostel or home environment causing you ...  NaN   2.424674  1.256795
# Do you lack confidence in your academic perform...  NaN   2.581257  1.288163
# Do you lack confidence in your choice of academ...  NaN   2.641756  1.305848
# Academic and extracurricular activities conflic...  NaN   2.756821  1.263008
# Do you attend classes regularly?                    NaN     3.2586  1.202543
# Have you gained/lost weight?                        NaN   2.398577  1.112485
# Which type of stress do you primarily experience?   768        NaN       NaN
#
#                                                      min   25%   50%   75%  \
# Gender                                               0.0   0.0   0.0   1.0
# Age                                                 14.0  19.0  19.0  20.0
# Have you recently experienced stress in your life?   1.0   2.0   3.0   4.0
# Have you noticed a rapid heartbeat or palpitati...   1.0   2.0   3.0   4.0
# Have you been dealing with anxiety or tension r...   1.0   2.0   2.0   3.0
# Do you face any sleep problems or difficulties ...   1.0   2.0   3.0   4.0
# Have you been dealing with anxiety or tension r...   1.0   2.0   2.0   4.0
# Have you been getting headaches more often than...   1.0   2.0   2.0   4.0
# Do you get irritated easily?                         1.0   2.0   3.0   4.0
# Do you have trouble concentrating on your acade...   1.0   2.0   3.0   4.0
# Have you been feeling sadness or low mood?           1.0   2.0   2.0   3.0
# Have you been experiencing any illness or healt...   1.0   1.0   2.0   3.0
# Do you often feel lonely or isolated?                1.0   1.0   2.0   3.0
# Do you feel overwhelmed with your academic work...   1.0   1.0   2.0   3.0
# Are you in competition with your peers, and doe...   1.0   2.0   2.0   3.0
# Do you find that your relationship often causes...   1.0   1.0   2.0   3.0
# Are you facing any difficulties with your profe...   1.0   1.0   2.0   3.0
# Is your working environment unpleasant or stres...   1.0   2.0   2.0   3.0
# Do you struggle to find time for relaxation and...   1.0   1.0   2.0   3.0
# Is your hostel or home environment causing you ...   1.0   1.0   2.0   3.0
# Do you lack confidence in your academic perform...   1.0   1.0   3.0   3.0
# Do you lack confidence in your choice of academ...   1.0   2.0   3.0   4.0
# Academic and extracurricular activities conflic...   1.0   2.0   3.0   4.0
# Do you attend classes regularly?                     1.0   2.0   3.0   4.0
# Have you gained/lost weight?                         1.0   2.0   2.0   3.0
# Which type of stress do you primarily experience?    NaN   NaN   NaN   NaN
#
#                                                       max
# Gender                                                1.0
# Age                                                 100.0
# Have you recently experienced stress in your life?    5.0
# Have you noticed a rapid heartbeat or palpitati...    5.0
# Have you been dealing with anxiety or tension r...    5.0
# Do you face any sleep problems or difficulties ...    5.0
# Have you been dealing with anxiety or tension r...    5.0
# Have you been getting headaches more often than...    5.0
# Do you get irritated easily?                          5.0
# Do you have trouble concentrating on your acade...    5.0
# Have you been feeling sadness or low mood?            5.0
# Have you been experiencing any illness or healt...    5.0
# Do you often feel lonely or isolated?                 5.0
# Do you feel overwhelmed with your academic work...    5.0
# Are you in competition with your peers, and doe...    5.0
# Do you find that your relationship often causes...    5.0
# Are you facing any difficulties with your profe...    5.0
# Is your working environment unpleasant or stres...    5.0
# Do you struggle to find time for relaxation and...    5.0
# Is your hostel or home environment causing you ...    5.0
# Do you lack confidence in your academic perform...    5.0
# Do you lack confidence in your choice of academ...    5.0
# Academic and extracurricular activities conflic...    5.0
# Do you attend classes regularly?                      5.0
# Have you gained/lost weight?                          5.0
# Which type of stress do you primarily experience?     NaN

# %% [markdown]
# ## 2. Handling Missing Values
#
# Survey data often has missing responses. Pandas provides simple methods to detect and handle missing values. We can choose to either remove rows with missing values or fill them with reasonable replacements.

# %%
# Check for missing values
df.isnull().sum()

# Example: Fill missing Age values with the median
df['Age'] = df['Age'].fillna(df['Age'].median())

# Example: Drop rows where 'Gender' is missing
df = df.dropna(subset=['Gender'])

# %% [markdown]
# ## 3. Removing Duplicates
#
# Sometimes survey data contains duplicate rows when participants accidentally submit multiple times. Removing duplicates ensures our analysis is not biased.

# %%
# Check for duplicate rows
df.duplicated().sum()

# Remove duplicates
df = df.drop_duplicates()

# %% [markdown]
# ## 4. Converting Numeric Codes to Meaningful Labels
#
# Survey data often uses numeric codes to represent categorical values. For example, gender might be coded as 0 and 1 instead of 'Female' and 'Male'. Converting these numeric codes to descriptive labels makes the data more readable and easier to interpret during analysis.

# %%
# Convert numeric gender codes to descriptive labels
gender_map = {0: 'Female', 1: 'Male'}
df['Gender'] = df['Gender'].map(gender_map)

# Show the unique values to verify the conversion
print("Unique values in Gender column after conversion:")
print(df['Gender'].unique())
# Out:
# Unique values in Gender column after conversion:
# ['Female' 'Male']

# %%
# Check the data type of Gender column and its values
print("Data type of Gender column:", df['Gender'].dtype)
print("\nUnique values in Gender column:")
print(df['Gender'].unique())
# Out:
# Data type of Gender column: int64
#
# Unique values in Gender column:
# [0 1]

# %% [markdown]
# ## 5. Transforming Data Types
#
# It is important that each column has the correct data type. For example, the 'Age' column should be numeric, and categorical responses should be converted to categories.

# %%
# Convert Age to integer
df['Age'] = df['Age'].astype(int)

# Convert Gender to categorical
df['Gender'] = df['Gender'].astype('category')

# %% [markdown]
# ## 6. A Slightly Complex Challenge
#
# Let us now try a slightly more complex cleaning task. Suppose we want to create a new column called **Stress_Level** based on the answers to three survey questions:
# - Have you recently experienced stress in your life?
# - Do you face any sleep problems or difficulties falling asleep?
# - Do you feel overwhelmed with your academic workload?
#
# We will compute the average of these three columns and use it to classify participants as having **Low**, **Medium**, or **High** stress levels.

# %%
# Calculate average of selected stress indicators
df['Stress_Score'] = df[[
    'Have you recently experienced stress in your life?',
    'Do you face any sleep problems or difficulties falling asleep?',
    'Do you feel overwhelmed with your academic workload?'
]].mean(axis=1)

# Create categories based on the score
df['Stress_Level'] = pd.cut(
    df['Stress_Score'],
    bins=[0, 2, 3.5, 5],
    labels=['Low', 'Medium', 'High']
)

df[['Stress_Score', 'Stress_Level']].head()
# Out:
#    Stress_Score Stress_Level
# 0      4.333333         High
# 1      1.333333          Low
# 2      3.666667         High
# 3      2.000000          Low
# 4      2.000000          Low
