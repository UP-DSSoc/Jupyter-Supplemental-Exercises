# %% [markdown]
# <img src="../img/UP Data Science Society Logo 2.png" width=700 />

# %% [markdown]
# # [3.1] Introduction to Pandas
#
# **Prepared by**:
# - Yuan Labuguen
#
# **Weekly Objectives**:
# - Learn to load and manipulate data using Pandas
# - Understand basic Pandas data structures and operations
# - Master data analysis and transformation techniques with Pandas

# %% [markdown]
# ## 1. Loading and Reading Data with Pandas
#
# Let's start by importing Pandas and learning different ways to load data.

# %%
# Import pandas
import pandas as pd
import numpy as np

# Load data from CSV
df = pd.read_csv("./Data/Stress_Dataset.csv")

# Display the first few rows
print("First few rows of the dataset:")
print(df.head())

# Create a DataFrame from a dictionary
data_dict = {
    'Name': ['John', 'Anna', 'Peter'],
    'Age': [25, 28, 30],
    'City': ['New York', 'Paris', 'London']
}
df_dict = pd.DataFrame(data_dict)
print("\nDataFrame from dictionary:")
print(df_dict)
# Out:
# First few rows of the dataset:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Have you been getting headaches more often than usual?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    Do you get irritated easily?  \
# 0                             1
# 1                             1
# 2                             4
# 3                             4
# 4                             4
#
#    Do you have trouble concentrating on your academic tasks?  ...  \
# 0                                                  2          ...
# 1                                                  4          ...
# 2                                                  2          ...
# 3                                                  3          ...
# 4                                                  4          ...
#
#    Are you facing any difficulties with your professors or instructors?  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    Is your working environment unpleasant or stressful?  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                  4
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    Is your hostel or home environment causing you difficulties?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you lack confidence in your academic performance?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  2
# 4                                                  2
#
#    Do you lack confidence in your choice of academic subjects?  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    Academic and extracurricular activities conflicting for you?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                 1                             2
# 1                                 4                             2
# 2                                 2                             1
# 3                                 5                             3
# 4                                 2                             2
#
#    Which type of stress do you primarily experience?
# 0  Eustress (Positive Stress) - Stress that motiv...
# 1  Eustress (Positive Stress) - Stress that motiv...
# 2  Eustress (Positive Stress) - Stress that motiv...
# 3  Eustress (Positive Stress) - Stress that motiv...
# 4  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]
#
# DataFrame from dictionary:
#     Name  Age      City
# 0   John   25  New York
# 1   Anna   28     Paris
# 2  Peter   30    London

# %% [markdown]
# ## 2. Understanding DataFrame Basics
#
# Let's explore the basic properties and methods of a Pandas DataFrame.

# %%
# Basic DataFrame information
print("DataFrame Info:")
print(df.info())

# Basic statistics of numeric columns
print("\nBasic Statistics:")
print(df.describe())

# DataFrame dimensions
print("\nDataFrame Shape (rows, columns):", df.shape)

# Column names
print("\nColumn Names:", df.columns.tolist())

# Data types of columns
print("\nData Types:")
print(df.dtypes)
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 26 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Gender                                                                843 non-null    int64
#  1   Age                                                                   843 non-null    int64
#  2   Have you recently experienced stress in your life?                    843 non-null    int64
#  3   Have you noticed a rapid heartbeat or palpitations?                   843 non-null    int64
#  4   Have you been dealing with anxiety or tension recently?               843 non-null    int64
#  5   Do you face any sleep problems or difficulties falling asleep?        843 non-null    int64
#  6   Have you been dealing with anxiety or tension recently?.1             843 non-null    int64
#  7   Have you been getting headaches more often than usual?                843 non-null    int64
#  8   Do you get irritated easily?                                          843 non-null    int64
#  9   Do you have trouble concentrating on your academic tasks?             843 non-null    int64
#  10  Have you been feeling sadness or low mood?                            843 non-null    int64
#  11  Have you been experiencing any illness or health issues?              843 non-null    int64
#  12  Do you often feel lonely or isolated?                                 843 non-null    int64
#  13  Do you feel overwhelmed with your academic workload?                  843 non-null    int64
#  14  Are you in competition with your peers, and does it affect you?       843 non-null    int64
#  15  Do you find that your relationship often causes you stress?           843 non-null    int64
#  16  Are you facing any difficulties with your professors or instructors?  843 non-null    int64
#  17  Is your working environment unpleasant or stressful?                  843 non-null    int64
#  18  Do you struggle to find time for relaxation and leisure activities?   843 non-null    int64
#  19  Is your hostel or home environment causing you difficulties?          843 non-null    int64
#  20  Do you lack confidence in your academic performance?                  843 non-null    int64
#  21  Do you lack confidence in your choice of academic subjects?           843 non-null    int64
#  22  Academic and extracurricular activities conflicting for you?          843 non-null    int64
#  23  Do you attend classes regularly?                                      843 non-null    int64
#  24  Have you gained/lost weight?                                          843 non-null    int64
#  25  Which type of stress do you primarily experience?                     843 non-null    object
# dtypes: int64(25), object(1)
# memory usage: 171.4+ KB
# None
#
# Basic Statistics:
#            Gender         Age  \
# count  843.000000  843.000000
# mean     0.349941   20.071174
# std      0.477234    5.429502
# min      0.000000   14.000000
# 25%      0.000000   19.000000
# 50%      0.000000   19.000000
# 75%      1.000000   20.000000
# max      1.000000  100.000000
#
#        Have you recently experienced stress in your life?  \
# count                                         843.000000
# mean                                            2.997628
# std                                             1.134639
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you noticed a rapid heartbeat or palpitations?  \
# count                                         843.000000
# mean                                            2.755635
# std                                             1.118650
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you been dealing with anxiety or tension recently?  \
# count                                         843.000000
# mean                                            2.543298
# std                                             1.201330
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Do you face any sleep problems or difficulties falling asleep?  \
# count                                         843.000000
# mean                                            2.786477
# std                                             1.266959
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you been dealing with anxiety or tension recently?.1  \
# count                                         843.000000
# mean                                            2.663108
# std                                             1.266376
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you been getting headaches more often than usual?  \
# count                                         843.000000
# mean                                            2.628707
# std                                             1.266593
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Do you get irritated easily?  \
# count                    843.000000
# mean                       2.702254
# std                        1.314213
# min                        1.000000
# 25%                        2.000000
# 50%                        3.000000
# 75%                        4.000000
# max                        5.000000
#
#        Do you have trouble concentrating on your academic tasks?  ...  \
# count                                         843.000000          ...
# mean                                            2.699881          ...
# std                                             1.313673          ...
# min                                             1.000000          ...
# 25%                                             2.000000          ...
# 50%                                             3.000000          ...
# 75%                                             4.000000          ...
# max                                             5.000000          ...
#
#        Do you find that your relationship often causes you stress?  \
# count                                         843.000000
# mean                                            2.514828
# std                                             1.241869
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Are you facing any difficulties with your professors or instructors?  \
# count                                         843.000000
# mean                                            2.447212
# std                                             1.195995
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Is your working environment unpleasant or stressful?  \
# count                                         843.000000
# mean                                            2.488731
# std                                             1.196116
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Do you struggle to find time for relaxation and leisure activities?  \
# count                                         843.000000
# mean                                            2.517200
# std                                             1.247563
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Is your hostel or home environment causing you difficulties?  \
# count                                         843.000000
# mean                                            2.424674
# std                                             1.256795
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Do you lack confidence in your academic performance?  \
# count                                         843.000000
# mean                                            2.581257
# std                                             1.288163
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Do you lack confidence in your choice of academic subjects?  \
# count                                         843.000000
# mean                                            2.641756
# std                                             1.305848
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Academic and extracurricular activities conflicting for you?  \
# count                                         843.000000
# mean                                            2.756821
# std                                             1.263008
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Do you attend classes regularly?  Have you gained/lost weight?
# count                        843.000000                    843.000000
# mean                           3.258600                      2.398577
# std                            1.202543                      1.112485
# min                            1.000000                      1.000000
# 25%                            2.000000                      2.000000
# 50%                            3.000000                      2.000000
# 75%                            4.000000                      3.000000
# max                            5.000000                      5.000000
#
# [8 rows x 25 columns]
#
# DataFrame Shape (rows, columns): (843, 26)
#
# Column Names: ['Gender', 'Age', 'Have you recently experienced stress in your life?', 'Have you noticed a rapid heartbeat or palpitations?', 'Have you been dealing with anxiety or tension recently?', 'Do you face any sleep problems or difficulties falling asleep?', 'Have you been dealing with anxiety or tension recently?.1', 'Have you been getting headaches more often than usual?', 'Do you get irritated easily?', 'Do you have trouble concentrating on your academic tasks?', 'Have you been feeling sadness or low mood?', 'Have you been experiencing any illness or health issues?', 'Do you often feel lonely or isolated?', 'Do you feel overwhelmed with your academic workload?', 'Are you in competition with your peers, and does it affect you?', 'Do you find that your relationship often causes you stress?', 'Are you facing any difficulties with your professors or instructors?', 'Is your working environment unpleasant or stressful?', 'Do you struggle to find time for relaxation and leisure activities?', 'Is your hostel or home environment causing you difficulties?', 'Do you lack confidence in your academic performance?', 'Do you lack confidence in your choice of academic subjects?', 'Academic and extracurricular activities conflicting for you?', 'Do you attend classes regularly?', 'Have you gained/lost weight?', 'Which type of stress do you primarily experience?']
#
# Data Types:
# Gender                                                                   int64
# Age                                                                      int64
# Have you recently experienced stress in your life?                       int64
# Have you noticed a rapid heartbeat or palpitations?                      int64
# Have you been dealing with anxiety or tension recently?                  int64
# Do you face any sleep problems or difficulties falling asleep?           int64
# Have you been dealing with anxiety or tension recently?.1                int64
# Have you been getting headaches more often than usual?                   int64
# Do you get irritated easily?                                             int64
# Do you have trouble concentrating on your academic tasks?                int64
# Have you been feeling sadness or low mood?                               int64
# Have you been experiencing any illness or health issues?                 int64
# Do you often feel lonely or isolated?                                    int64
# Do you feel overwhelmed with your academic workload?                     int64
# Are you in competition with your peers, and does it affect you?          int64
# Do you find that your relationship often causes you stress?              int64
# Are you facing any difficulties with your professors or instructors?     int64
# Is your working environment unpleasant or stressful?                     int64
# Do you struggle to find time for relaxation and leisure activities?      int64
# Is your hostel or home environment causing you difficulties?             int64
# Do you lack confidence in your academic performance?                     int64
# Do you lack confidence in your choice of academic subjects?              int64
# Academic and extracurricular activities conflicting for you?             int64
# Do you attend classes regularly?                                         int64
# Have you gained/lost weight?                                             int64
# Which type of stress do you primarily experience?                       object
# dtype: object

# %% [markdown]
# ## 3. Data Selection and Indexing
#
# Learn different ways to select and index data in a DataFrame.

# %%
# Select a single column
print("Single column selection:")
print(df.iloc[:, 0])  # First column

# Select multiple columns
print("\nMultiple column selection:")
print(df.iloc[:, [0, 1]])  # First two columns

# Select rows by index
print("\nRow selection by index:")
print(df.iloc[0:3])  # First three rows

# Select specific rows and columns
print("\nSpecific rows and columns:")
print(df.iloc[0:3, 0:2])  # First three rows and first two columns

# Using loc for label-based indexing
print("\nLabel-based indexing with column names:")
print(df.loc[:, df.columns[0:2]])  # First two columns by name
# Out:
# Single column selection:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 838    0
# 839    1
# 840    1
# 841    0
# 842    0
# Name: Gender, Length: 843, dtype: int64
#
# Multiple column selection:
#      Gender  Age
# 0         0   20
# 1         0   20
# 2         0   20
# 3         1   20
# 4         0   20
# ..      ...  ...
# 838       0   21
# 839       1   19
# 840       1   19
# 841       0   20
# 842       0   19
#
# [843 rows x 2 columns]
#
# Row selection by index:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
#
#    Have you been getting headaches more often than usual?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
#
#    Do you get irritated easily?  \
# 0                             1
# 1                             1
# 2                             4
#
#    Do you have trouble concentrating on your academic tasks?  ...  \
# 0                                                  2          ...
# 1                                                  4          ...
# 2                                                  2          ...
#
#    Are you facing any difficulties with your professors or instructors?  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
#
#    Is your working environment unpleasant or stressful?  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
#
#    Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                  4
# 1                                                  1
# 2                                                  2
#
#    Is your hostel or home environment causing you difficulties?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
#
#    Do you lack confidence in your academic performance?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
#
#    Do you lack confidence in your choice of academic subjects?  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
#
#    Academic and extracurricular activities conflicting for you?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
#
#    Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                 1                             2
# 1                                 4                             2
# 2                                 2                             1
#
#    Which type of stress do you primarily experience?
# 0  Eustress (Positive Stress) - Stress that motiv...
# 1  Eustress (Positive Stress) - Stress that motiv...
# 2  Eustress (Positive Stress) - Stress that motiv...
#
# [3 rows x 26 columns]
#
# Specific rows and columns:
#    Gender  Age
# 0       0   20
# 1       0   20
# 2       0   20
#
# Label-based indexing with column names:
#      Gender  Age
# 0         0   20
# 1         0   20
# 2         0   20
# 3         1   20
# 4         0   20
# ..      ...  ...
# 838       0   21
# 839       1   19
# 840       1   19
# 841       0   20
# 842       0   19
#
# [843 rows x 2 columns]

# %% [markdown]
# ## 4. Data Filtering and Boolean Indexing
#
# Learn how to filter data using boolean conditions.

# %%
# Simple boolean condition
numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) > 0:
    first_numeric = numeric_cols[0]
    condition = df[first_numeric] > df[first_numeric].mean()
    print(f"Rows where {first_numeric} is above mean:")
    print(df[condition].head())

# Multiple conditions
if len(numeric_cols) > 1:
    second_numeric = numeric_cols[1]
    condition1 = df[first_numeric] > df[first_numeric].mean()
    condition2 = df[second_numeric] < df[second_numeric].median()
    print(f"\nRows where {first_numeric} is above mean AND {second_numeric} is below median:")
    print(df[condition1 & condition2].head())

# Using isin()
if len(df) > 5:
    values_to_check = df.iloc[0:5, 0].tolist()
    print("\nRows where first column values are in the first 5 values:")
    print(df[df.iloc[:, 0].isin(values_to_check)].head())
# Out:
# Rows where Gender is above mean:
#     Gender  Age  Have you recently experienced stress in your life?  \
# 3        1   20                                                  3
# 10       1   19                                                  2
# 11       1   20                                                  5
# 15       1   19                                                  4
# 18       1   18                                                  1
#
#     Have you noticed a rapid heartbeat or palpitations?  \
# 3                                                   4
# 10                                                  1
# 11                                                  3
# 15                                                  4
# 18                                                  1
#
#     Have you been dealing with anxiety or tension recently?  \
# 3                                                   3
# 10                                                  2
# 11                                                  2
# 15                                                  3
# 18                                                  4
#
#     Do you face any sleep problems or difficulties falling asleep?  \
# 3                                                   2
# 10                                                  4
# 11                                                  4
# 15                                                  5
# 18                                                  4
#
#     Have you been dealing with anxiety or tension recently?.1  \
# 3                                                   2
# 10                                                  3
# 11                                                  2
# 15                                                  1
# 18                                                  3
#
#     Have you been getting headaches more often than usual?  \
# 3                                                   3
# 10                                                  3
# 11                                                  3
# 15                                                  2
# 18                                                  3
#
#     Do you get irritated easily?  \
# 3                              4
# 10                             2
# 11                             4
# 15                             2
# 18                             1
#
#     Do you have trouble concentrating on your academic tasks?  ...  \
# 3                                                   3          ...
# 10                                                  2          ...
# 11                                                  2          ...
# 15                                                  3          ...
# 18                                                  1          ...
#
#     Are you facing any difficulties with your professors or instructors?  \
# 3                                                   1
# 10                                                  1
# 11                                                  5
# 15                                                  3
# 18                                                  5
#
#     Is your working environment unpleasant or stressful?  \
# 3                                                   1
# 10                                                  1
# 11                                                  1
# 15                                                  4
# 18                                                  5
#
#     Do you struggle to find time for relaxation and leisure activities?  \
# 3                                                   2
# 10                                                  1
# 11                                                  1
# 15                                                  1
# 18                                                  5
#
#     Is your hostel or home environment causing you difficulties?  \
# 3                                                   1
# 10                                                  1
# 11                                                  1
# 15                                                  2
# 18                                                  5
#
#     Do you lack confidence in your academic performance?  \
# 3                                                   2
# 10                                                  1
# 11                                                  1
# 15                                                  3
# 18                                                  5
#
#     Do you lack confidence in your choice of academic subjects?  \
# 3                                                   1
# 10                                                  1
# 11                                                  1
# 15                                                  2
# 18                                                  5
#
#     Academic and extracurricular activities conflicting for you?  \
# 3                                                   1
# 10                                                  2
# 11                                                  2
# 15                                                  2
# 18                                                  3
#
#     Do you attend classes regularly?  Have you gained/lost weight?  \
# 3                                  5                             3
# 10                                 3                             1
# 11                                 3                             1
# 15                                 2                             3
# 18                                 3                             2
#
#     Which type of stress do you primarily experience?
# 3   Eustress (Positive Stress) - Stress that motiv...
# 10  No Stress - Currently experiencing minimal to ...
# 11  Eustress (Positive Stress) - Stress that motiv...
# 15  Eustress (Positive Stress) - Stress that motiv...
# 18  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]
#
# Rows where Gender is above mean AND Age is below median:
#     Gender  Age  Have you recently experienced stress in your life?  \
# 18       1   18                                                  1
# 34       1   17                                                  3
# 52       1   18                                                  4
# 61       1   18                                                  3
# 72       1   18                                                  3
#
#     Have you noticed a rapid heartbeat or palpitations?  \
# 18                                                  1
# 34                                                  3
# 52                                                  2
# 61                                                  3
# 72                                                  4
#
#     Have you been dealing with anxiety or tension recently?  \
# 18                                                  4
# 34                                                  4
# 52                                                  5
# 61                                                  3
# 72                                                  4
#
#     Do you face any sleep problems or difficulties falling asleep?  \
# 18                                                  4
# 34                                                  4
# 52                                                  2
# 61                                                  3
# 72                                                  2
#
#     Have you been dealing with anxiety or tension recently?.1  \
# 18                                                  3
# 34                                                  3
# 52                                                  2
# 61                                                  1
# 72                                                  3
#
#     Have you been getting headaches more often than usual?  \
# 18                                                  3
# 34                                                  4
# 52                                                  2
# 61                                                  2
# 72                                                  5
#
#     Do you get irritated easily?  \
# 18                             1
# 34                             5
# 52                             2
# 61                             1
# 72                             2
#
#     Do you have trouble concentrating on your academic tasks?  ...  \
# 18                                                  1          ...
# 34                                                  2          ...
# 52                                                  3          ...
# 61                                                  4          ...
# 72                                                  1          ...
#
#     Are you facing any difficulties with your professors or instructors?  \
# 18                                                  5
# 34                                                  2
# 52                                                  2
# 61                                                  1
# 72                                                  3
#
#     Is your working environment unpleasant or stressful?  \
# 18                                                  5
# 34                                                  2
# 52                                                  2
# 61                                                  2
# 72                                                  1
#
#     Do you struggle to find time for relaxation and leisure activities?  \
# 18                                                  5
# 34                                                  3
# 52                                                  2
# 61                                                  2
# 72                                                  3
#
#     Is your hostel or home environment causing you difficulties?  \
# 18                                                  5
# 34                                                  2
# 52                                                  2
# 61                                                  3
# 72                                                  2
#
#     Do you lack confidence in your academic performance?  \
# 18                                                  5
# 34                                                  2
# 52                                                  2
# 61                                                  4
# 72                                                  3
#
#     Do you lack confidence in your choice of academic subjects?  \
# 18                                                  5
# 34                                                  3
# 52                                                  2
# 61                                                  1
# 72                                                  3
#
#     Academic and extracurricular activities conflicting for you?  \
# 18                                                  3
# 34                                                  4
# 52                                                  3
# 61                                                  5
# 72                                                  3
#
#     Do you attend classes regularly?  Have you gained/lost weight?  \
# 18                                 3                             2
# 34                                 3                             2
# 52                                 5                             3
# 61                                 5                             2
# 72                                 3                             2
#
#     Which type of stress do you primarily experience?
# 18  Eustress (Positive Stress) - Stress that motiv...
# 34  Eustress (Positive Stress) - Stress that motiv...
# 52  Eustress (Positive Stress) - Stress that motiv...
# 61  Eustress (Positive Stress) - Stress that motiv...
# 72  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]
#
# Rows where first column values are in the first 5 values:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Have you been getting headaches more often than usual?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    Do you get irritated easily?  \
# 0                             1
# 1                             1
# 2                             4
# 3                             4
# 4                             4
#
#    Do you have trouble concentrating on your academic tasks?  ...  \
# 0                                                  2          ...
# 1                                                  4          ...
# 2                                                  2          ...
# 3                                                  3          ...
# 4                                                  4          ...
#
#    Are you facing any difficulties with your professors or instructors?  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    Is your working environment unpleasant or stressful?  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                  4
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    Is your hostel or home environment causing you difficulties?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you lack confidence in your academic performance?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  2
# 4                                                  2
#
#    Do you lack confidence in your choice of academic subjects?  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    Academic and extracurricular activities conflicting for you?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                 1                             2
# 1                                 4                             2
# 2                                 2                             1
# 3                                 5                             3
# 4                                 2                             2
#
#    Which type of stress do you primarily experience?
# 0  Eustress (Positive Stress) - Stress that motiv...
# 1  Eustress (Positive Stress) - Stress that motiv...
# 2  Eustress (Positive Stress) - Stress that motiv...
# 3  Eustress (Positive Stress) - Stress that motiv...
# 4  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 5. Basic Data Analysis Operations
#
# Explore basic statistical operations and data analysis techniques.

# %%
# Basic statistics for numeric columns
numeric_cols = df.select_dtypes(include=[np.number])
categorical_cols = df.select_dtypes(exclude=[np.number])

# Identify meaningful numeric columns (excluding categorical codes)
meaningful_numeric = numeric_cols.columns[~numeric_cols.columns.str.contains('id|gender|category|type', case=False)].tolist()

if meaningful_numeric:
    print("Basic Statistics for Numeric Columns (excluding categorical codes):")
    print("\nMean:")
    print(df[meaningful_numeric].mean())
    print("\nMedian:")
    print(df[meaningful_numeric].median())
    print("\nStandard Deviation:")
    print(df[meaningful_numeric].std())

# Value counts for categorical columns
if not categorical_cols.empty:
    print("\nCategory Distributions:")
    for col in categorical_cols.columns[:2]:  # Show first two categorical columns
        print(f"\nDistribution of {col}:")
        print(df[col].value_counts())
        print(f"Number of unique {col} values:", df[col].nunique())

# Sorting data
if meaningful_numeric:
    sort_col = meaningful_numeric[0]
    print(f"\nTop 5 rows sorted by {sort_col}:")
    print(df.sort_values(by=sort_col, ascending=False).head())
# Out:
# Basic Statistics for Numeric Columns (excluding categorical codes):
#
# Mean:
# Age                                                                     20.071174
# Have you recently experienced stress in your life?                       2.997628
# Have you been dealing with anxiety or tension recently?                  2.543298
# Do you face any sleep problems or difficulties falling asleep?           2.786477
# Have you been dealing with anxiety or tension recently?.1                2.663108
# Have you been getting headaches more often than usual?                   2.628707
# Do you get irritated easily?                                             2.702254
# Do you have trouble concentrating on your academic tasks?                2.699881
# Have you been feeling sadness or low mood?                               2.584816
# Have you been experiencing any illness or health issues?                 2.549229
# Do you often feel lonely or isolated?                                    2.497034
# Do you feel overwhelmed with your academic workload?                     2.504152
# Are you in competition with your peers, and does it affect you?          2.485172
# Do you find that your relationship often causes you stress?              2.514828
# Are you facing any difficulties with your professors or instructors?     2.447212
# Is your working environment unpleasant or stressful?                     2.488731
# Do you struggle to find time for relaxation and leisure activities?      2.517200
# Is your hostel or home environment causing you difficulties?             2.424674
# Academic and extracurricular activities conflicting for you?             2.756821
# Do you attend classes regularly?                                         3.258600
# Have you gained/lost weight?                                             2.398577
# dtype: float64
#
# Median:
# Age                                                                     19.0
# Have you recently experienced stress in your life?                       3.0
# Have you been dealing with anxiety or tension recently?                  2.0
# Do you face any sleep problems or difficulties falling asleep?           3.0
# Have you been dealing with anxiety or tension recently?.1                2.0
# Have you been getting headaches more often than usual?                   2.0
# Do you get irritated easily?                                             3.0
# Do you have trouble concentrating on your academic tasks?                3.0
# Have you been feeling sadness or low mood?                               2.0
# Have you been experiencing any illness or health issues?                 2.0
# Do you often feel lonely or isolated?                                    2.0
# Do you feel overwhelmed with your academic workload?                     2.0
# Are you in competition with your peers, and does it affect you?          2.0
# Do you find that your relationship often causes you stress?              2.0
# Are you facing any difficulties with your professors or instructors?     2.0
# Is your working environment unpleasant or stressful?                     2.0
# Do you struggle to find time for relaxation and leisure activities?      2.0
# Is your hostel or home environment causing you difficulties?             2.0
# Academic and extracurricular activities conflicting for you?             3.0
# Do you attend classes regularly?                                         3.0
# Have you gained/lost weight?                                             2.0
# dtype: float64
#
# Standard Deviation:
# Age                                                                     5.429502
# Have you recently experienced stress in your life?                      1.134639
# Have you been dealing with anxiety or tension recently?                 1.201330
# Do you face any sleep problems or difficulties falling asleep?          1.266959
# Have you been dealing with anxiety or tension recently?.1               1.266376
# Have you been getting headaches more often than usual?                  1.266593
# Do you get irritated easily?                                            1.314213
# Do you have trouble concentrating on your academic tasks?               1.313673
# Have you been feeling sadness or low mood?                              1.233290
# Have you been experiencing any illness or health issues?                1.254307
# Do you often feel lonely or isolated?                                   1.258106
# Do you feel overwhelmed with your academic workload?                    1.250527
# Are you in competition with your peers, and does it affect you?         1.217726
# Do you find that your relationship often causes you stress?             1.241869
# Are you facing any difficulties with your professors or instructors?    1.195995
# Is your working environment unpleasant or stressful?                    1.196116
# Do you struggle to find time for relaxation and leisure activities?     1.247563
# Is your hostel or home environment causing you difficulties?            1.256795
# Academic and extracurricular activities conflicting for you?            1.263008
# Do you attend classes regularly?                                        1.202543
# Have you gained/lost weight?                                            1.112485
# dtype: float64
#
# Category Distributions:
#
# Distribution of Which type of stress do you primarily experience?:
# Which type of stress do you primarily experience?
# Eustress (Positive Stress) - Stress that motivates and enhances performance.       768
# No Stress - Currently experiencing minimal to no stress.                            43
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.     32
# Name: count, dtype: int64
# Number of unique Which type of stress do you primarily experience? values: 3
#
# Top 5 rows sorted by Age:
#      Gender  Age  Have you recently experienced stress in your life?  \
# 483       0  100                                                  5
# 749       1  100                                                  5
# 217       0  100                                                  5
# 592       0   41                                                  2
# 60        0   41                                                  2
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 483                                                  1
# 749                                                  5
# 217                                                  5
# 592                                                  1
# 60                                                   1
#
#      Have you been dealing with anxiety or tension recently?  \
# 483                                                  3
# 749                                                  1
# 217                                                  1
# 592                                                  4
# 60                                                   4
#
#      Do you face any sleep problems or difficulties falling asleep?  \
# 483                                                  3
# 749                                                  2
# 217                                                  2
# 592                                                  4
# 60                                                   2
#
#      Have you been dealing with anxiety or tension recently?.1  \
# 483                                                  3
# 749                                                  1
# 217                                                  1
# 592                                                  3
# 60                                                   4
#
#      Have you been getting headaches more often than usual?  \
# 483                                                  3
# 749                                                  3
# 217                                                  3
# 592                                                  3
# 60                                                   1
#
#      Do you get irritated easily?  \
# 483                             3
# 749                             3
# 217                             3
# 592                             1
# 60                              1
#
#      Do you have trouble concentrating on your academic tasks?  ...  \
# 483                                                  3          ...
# 749                                                  2          ...
# 217                                                  2          ...
# 592                                                  3          ...
# 60                                                   4          ...
#
#      Are you facing any difficulties with your professors or instructors?  \
# 483                                                  3
# 749                                                  4
# 217                                                  4
# 592                                                  2
# 60                                                   1
#
#      Is your working environment unpleasant or stressful?  \
# 483                                                  2
# 749                                                  1
# 217                                                  1
# 592                                                  2
# 60                                                   2
#
#      Do you struggle to find time for relaxation and leisure activities?  \
# 483                                                  2
# 749                                                  1
# 217                                                  1
# 592                                                  3
# 60                                                   1
#
#      Is your hostel or home environment causing you difficulties?  \
# 483                                                  3
# 749                                                  1
# 217                                                  1
# 592                                                  5
# 60                                                   5
#
#      Do you lack confidence in your academic performance?  \
# 483                                                  3
# 749                                                  3
# 217                                                  3
# 592                                                  3
# 60                                                   1
#
#      Do you lack confidence in your choice of academic subjects?  \
# 483                                                  2
# 749                                                  4
# 217                                                  4
# 592                                                  4
# 60                                                   2
#
#      Academic and extracurricular activities conflicting for you?  \
# 483                                                  2
# 749                                                  5
# 217                                                  5
# 592                                                  2
# 60                                                   2
#
#      Do you attend classes regularly?  Have you gained/lost weight?  \
# 483                                 3                             2
# 749                                 1                             5
# 217                                 1                             5
# 592                                 4                             2
# 60                                  4                             2
#
#      Which type of stress do you primarily experience?
# 483  Eustress (Positive Stress) - Stress that motiv...
# 749  Eustress (Positive Stress) - Stress that motiv...
# 217  Eustress (Positive Stress) - Stress that motiv...
# 592  Eustress (Positive Stress) - Stress that motiv...
# 60   Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 6. Handling Missing Data
#
# Learn how to identify and handle missing data in your DataFrame.

# %%
# Check for missing values
print("Missing values in each column:")
print(df.isnull().sum())

# Create a sample DataFrame with missing values
df_missing = df.copy()
if len(df) > 0 and len(df.columns) > 0:
    df_missing.iloc[0:3, 0] = np.nan

# Different ways to handle missing values
print("\nDropping rows with missing values:")
print(df_missing.dropna().head())

print("\nFilling missing values with mean (numeric columns):")
numeric_cols = df_missing.select_dtypes(include=[np.number])
if not numeric_cols.empty:
    df_filled = df_missing.copy()
    for col in numeric_cols.columns:
        df_filled[col] = df_filled[col].fillna(df_filled[col].mean())
    print(df_filled.head())
# Out:
# Missing values in each column:
# Gender                                                                  0
# Age                                                                     0
# Have you recently experienced stress in your life?                      0
# Have you noticed a rapid heartbeat or palpitations?                     0
# Have you been dealing with anxiety or tension recently?                 0
# Do you face any sleep problems or difficulties falling asleep?          0
# Have you been dealing with anxiety or tension recently?.1               0
# Have you been getting headaches more often than usual?                  0
# Do you get irritated easily?                                            0
# Do you have trouble concentrating on your academic tasks?               0
# Have you been feeling sadness or low mood?                              0
# Have you been experiencing any illness or health issues?                0
# Do you often feel lonely or isolated?                                   0
# Do you feel overwhelmed with your academic workload?                    0
# Are you in competition with your peers, and does it affect you?         0
# Do you find that your relationship often causes you stress?             0
# Are you facing any difficulties with your professors or instructors?    0
# Is your working environment unpleasant or stressful?                    0
# Do you struggle to find time for relaxation and leisure activities?     0
# Is your hostel or home environment causing you difficulties?            0
# Do you lack confidence in your academic performance?                    0
# Do you lack confidence in your choice of academic subjects?             0
# Academic and extracurricular activities conflicting for you?            0
# Do you attend classes regularly?                                        0
# Have you gained/lost weight?                                            0
# Which type of stress do you primarily experience?                       0
# dtype: int64
#
# Dropping rows with missing values:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 3     1.0   20                                                  3
# 4     0.0   20                                                  3
# 5     0.0   20                                                  3
# 6     0.0   20                                                  2
# 7     0.0   20                                                  5
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 3                                                  4
# 4                                                  3
# 5                                                  4
# 6                                                  2
# 7                                                  5
#
#    Have you been dealing with anxiety or tension recently?  \
# 3                                                  3
# 4                                                  3
# 5                                                  3
# 6                                                  1
# 7                                                  5
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 3                                                  2
# 4                                                  2
# 5                                                  2
# 6                                                  4
# 7                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 3                                                  2
# 4                                                  2
# 5                                                  3
# 6                                                  4
# 7                                                  4
#
#    Have you been getting headaches more often than usual?  \
# 3                                                  3
# 4                                                  4
# 5                                                  3
# 6                                                  3
# 7                                                  2
#
#    Do you get irritated easily?  \
# 3                             4
# 4                             4
# 5                             4
# 6                             4
# 7                             1
#
#    Do you have trouble concentrating on your academic tasks?  ...  \
# 3                                                  3          ...
# 4                                                  4          ...
# 5                                                  1          ...
# 6                                                  1          ...
# 7                                                  1          ...
#
#    Are you facing any difficulties with your professors or instructors?  \
# 3                                                  1
# 4                                                  2
# 5                                                  2
# 6                                                  4
# 7                                                  1
#
#    Is your working environment unpleasant or stressful?  \
# 3                                                  1
# 4                                                  3
# 5                                                  3
# 6                                                  4
# 7                                                  4
#
#    Do you struggle to find time for relaxation and leisure activities?  \
# 3                                                  2
# 4                                                  1
# 5                                                  1
# 6                                                  2
# 7                                                  2
#
#    Is your hostel or home environment causing you difficulties?  \
# 3                                                  1
# 4                                                  2
# 5                                                  2
# 6                                                  3
# 7                                                  4
#
#    Do you lack confidence in your academic performance?  \
# 3                                                  2
# 4                                                  2
# 5                                                  3
# 6                                                  4
# 7                                                  3
#
#    Do you lack confidence in your choice of academic subjects?  \
# 3                                                  1
# 4                                                  4
# 5                                                  2
# 6                                                  3
# 7                                                  1
#
#    Academic and extracurricular activities conflicting for you?  \
# 3                                                  1
# 4                                                  2
# 5                                                  4
# 6                                                  3
# 7                                                  1
#
#    Do you attend classes regularly?  Have you gained/lost weight?  \
# 3                                 5                             3
# 4                                 2                             2
# 5                                 4                             4
# 6                                 3                             2
# 7                                 1                             5
#
#    Which type of stress do you primarily experience?
# 3  Eustress (Positive Stress) - Stress that motiv...
# 4  Eustress (Positive Stress) - Stress that motiv...
# 5  Eustress (Positive Stress) - Stress that motiv...
# 6  Eustress (Positive Stress) - Stress that motiv...
# 7  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]
#
# Filling missing values with mean (numeric columns):
#     Gender  Age  Have you recently experienced stress in your life?  \
# 0  0.35119   20                                                  3
# 1  0.35119   20                                                  2
# 2  0.35119   20                                                  5
# 3  1.00000   20                                                  3
# 4  0.00000   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Have you been dealing with anxiety or tension recently?.1  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Have you been getting headaches more often than usual?  \
# 0                                                  2
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    Do you get irritated easily?  \
# 0                             1
# 1                             1
# 2                             4
# 3                             4
# 4                             4
#
#    Do you have trouble concentrating on your academic tasks?  ...  \
# 0                                                  2          ...
# 1                                                  4          ...
# 2                                                  2          ...
# 3                                                  3          ...
# 4                                                  4          ...
#
#    Are you facing any difficulties with your professors or instructors?  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#    Is your working environment unpleasant or stressful?  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  3
#
#    Do you struggle to find time for relaxation and leisure activities?  \
# 0                                                  4
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#    Is your hostel or home environment causing you difficulties?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you lack confidence in your academic performance?  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  2
# 4                                                  2
#
#    Do you lack confidence in your choice of academic subjects?  \
# 0                                                  1
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
#    Academic and extracurricular activities conflicting for you?  \
# 0                                                  3
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Do you attend classes regularly?  Have you gained/lost weight?  \
# 0                                 1                             2
# 1                                 4                             2
# 2                                 2                             1
# 3                                 5                             3
# 4                                 2                             2
#
#    Which type of stress do you primarily experience?
# 0  Eustress (Positive Stress) - Stress that motiv...
# 1  Eustress (Positive Stress) - Stress that motiv...
# 2  Eustress (Positive Stress) - Stress that motiv...
# 3  Eustress (Positive Stress) - Stress that motiv...
# 4  Eustress (Positive Stress) - Stress that motiv...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 7. Grouping and Aggregation
#
# Learn how to group data and perform aggregation operations.

# %%
# Basic groupby operations
if len(df.columns) >= 2:
    # Identify meaningful columns for grouping and aggregation
    numeric_cols = df.select_dtypes(include=[np.number])
    categorical_cols = df.select_dtypes(exclude=[np.number])
    
    # Filter out numeric columns that shouldn't be aggregated
    meaningful_numeric = numeric_cols.columns[~numeric_cols.columns.str.contains('id|gender|category|type', case=False)].tolist()
    
    if len(categorical_cols) > 0 and len(meaningful_numeric) > 0:
        # Single column grouping
        group_col = categorical_cols.columns[0]  # First categorical column
        agg_col = meaningful_numeric[0]  # First meaningful numeric column
        
        print(f"Analysis grouped by {group_col}:")
        grouped_stats = df.groupby(group_col)[meaningful_numeric].agg([
            'count',    # Number of records
            'mean',     # Average
            'std',      # Standard deviation
            'min',      # Minimum value
            'max'       # Maximum value
        ])
        print(grouped_stats)
        
        # Calculate group sizes and percentages
        group_sizes = df[group_col].value_counts()
        group_percentages = df[group_col].value_counts(normalize=True) * 100
        
        print(f"\nDistribution of {group_col}:")
        for group in group_sizes.index:
            print(f"{group}: {group_sizes[group]} records ({group_percentages[group]:.1f}%)")
        
        # Multiple column grouping (only if we have 2 or more categorical columns)
        num_cat_cols = len(categorical_cols.columns)
        if num_cat_cols >= 2:
            print(f"\nFound {num_cat_cols} categorical columns. Performing multi-column grouping:")
            group_cols = list(categorical_cols.columns[:2])  # First two categorical columns
            print(f"Analyzing groups by: {group_cols[0]} and {group_cols[1]}")
            multi_grouped = df.groupby(group_cols)[agg_col].agg([
                'count',
                'mean',
                'std'
            ])
            print(multi_grouped)
        else:
            print(f"\nOnly {num_cat_cols} categorical column(s) found. Need at least 2 for multi-column grouping.")
    else:
        if len(categorical_cols) == 0:
            print("No categorical columns found for grouping.")
        if len(meaningful_numeric) == 0:
            print("No meaningful numeric columns found for aggregation.")
else:
    print("Not enough columns for grouping analysis.")
# Out:
# Analysis grouped by Which type of stress do you primarily experience?:
#                                                      Age                       \
#                                                    count       mean       std
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...    32  20.625000  3.338437
# Eustress (Positive Stress) - Stress that motiva...   768  20.091146  5.579533
# No Stress - Currently experiencing minimal to n...    43  19.302326  3.661478
#
#                                                              \
#                                                    min  max
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...  17   37
# Eustress (Positive Stress) - Stress that motiva...  14  100
# No Stress - Currently experiencing minimal to n...  14   41
#
#                                                    Have you recently experienced stress in your life?  \
#                                                                                                 count
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...                                                 32
# Eustress (Positive Stress) - Stress that motiva...                                                768
# No Stress - Currently experiencing minimal to n...                                                 43
#
#                                                                             \
#                                                         mean       std min
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...  3.937500  0.913607   2
# Eustress (Positive Stress) - Stress that motiva...  3.003906  1.118173   1
# No Stress - Currently experiencing minimal to n...  2.186047  1.006072   1
#
#                                                         ...  \
#                                                    max  ...
# Which type of stress do you primarily experience?       ...
# Distress (Negative Stress) - Stress that causes...   5  ...
# Eustress (Positive Stress) - Stress that motiva...   5  ...
# No Stress - Currently experiencing minimal to n...   5  ...
#
#                                                    Do you attend classes regularly?  \
#                                                                               count
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...                               32
# Eustress (Positive Stress) - Stress that motiva...                              768
# No Stress - Currently experiencing minimal to n...                               43
#
#                                                                             \
#                                                         mean       std min
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...  3.812500  0.965117   2
# Eustress (Positive Stress) - Stress that motiva...  3.278646  1.182428   1
# No Stress - Currently experiencing minimal to n...  2.488372  1.386535   1
#
#                                                         \
#                                                    max
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...   5
# Eustress (Positive Stress) - Stress that motiva...   5
# No Stress - Currently experiencing minimal to n...   5
#
#                                                    Have you gained/lost weight?  \
#                                                                           count
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...                           32
# Eustress (Positive Stress) - Stress that motiva...                          768
# No Stress - Currently experiencing minimal to n...                           43
#
#
#                                                         mean       std min max
# Which type of stress do you primarily experience?
# Distress (Negative Stress) - Stress that causes...  3.218750  1.453236   1   5
# Eustress (Positive Stress) - Stress that motiva...  2.406250  1.086392   1   5
# No Stress - Currently experiencing minimal to n...  1.651163  0.783269   1   4
#
# [3 rows x 105 columns]
#
# Distribution of Which type of stress do you primarily experience?:
# Eustress (Positive Stress) - Stress that motivates and enhances performance.: 768 records (91.1%)
# No Stress - Currently experiencing minimal to no stress.: 43 records (5.1%)
# Distress (Negative Stress) - Stress that causes anxiety and impairs well-being.: 32 records (3.8%)
#
# Only 1 categorical column(s) found. Need at least 2 for multi-column grouping.

# %% [markdown]
# ## 8. Data Manipulation and Transformation
#
# Learn how to manipulate and transform your data using Pandas.

# %% [markdown]
# ### Note about DataFrame Indices and Display
# In Pandas, each row in a DataFrame has an index. By default:
# - Indices start at 0 (unlike Excel which starts at 1)
# - The `head()` function shows the first 5 rows (indices 0-4)
# - These numbers on the left are just row labels, not data values
# - You can think of them like line numbers or row IDs
#
# When we display DataFrame results using `print(df.head())`, you'll see:
# ```
#    column1  column2  column3
# 0    value    value    value    <- Row with index 0
# 1    value    value    value    <- Row with index 1
# 2    value    value    value    <- Row with index 2
# 3    value    value    value    <- Row with index 3
# 4    value    value    value    <- Row with index 4
# ```

# %%
# Let's work with our simple dictionary DataFrame from section 1
data_dict = {
    'Name': ['John', 'Anna', 'Peter'],
    'Age': [25, 28, 30],
    'City': ['New York', 'Paris', 'London']
}
df_simple = pd.DataFrame(data_dict)
print("Original DataFrame:")
print(df_simple)

# 1. Adding a new column by transforming Age
print("\n1. Creating new column by doubling Age:")
df_simple['Age_Doubled'] = df_simple['Age'] * 2
print(df_simple)

# 2. Applying a custom function to Age
print("\n2. Adding 5 years to Age using a custom function:")
df_simple['Age_Plus_5'] = df_simple['Age'].apply(lambda x: x + 5)
print(df_simple)

# 3. Conditional transformation
print("\n3. Creating age category column:")
df_simple['Age_Category'] = df_simple['Age'].apply(
    lambda x: 'Young' if x < 27 else 'Adult')
print(df_simple)

# 4. String manipulation on Name column
print("\n4. Creating column with uppercase names:")
df_simple['Name_Upper'] = df_simple['Name'].str.upper()
print(df_simple)

# Clean up - remove the columns we created
df_simple = df_simple.drop(['Age_Doubled', 'Age_Plus_5', 
                          'Age_Category', 'Name_Upper'], axis=1)
print("\nBack to original DataFrame:")
print(df_simple)
# Out:
# All columns in the dataset:
# ['Gender', 'Age', 'Have you recently experienced stress in your life?', 'Have you noticed a rapid heartbeat or palpitations?', 'Have you been dealing with anxiety or tension recently?', 'Do you face any sleep problems or difficulties falling asleep?', 'Have you been dealing with anxiety or tension recently?.1', 'Have you been getting headaches more often than usual?', 'Do you get irritated easily?', 'Do you have trouble concentrating on your academic tasks?', 'Have you been feeling sadness or low mood?', 'Have you been experiencing any illness or health issues?', 'Do you often feel lonely or isolated?', 'Do you feel overwhelmed with your academic workload?', 'Are you in competition with your peers, and does it affect you?', 'Do you find that your relationship often causes you stress?', 'Are you facing any difficulties with your professors or instructors?', 'Is your working environment unpleasant or stressful?', 'Do you struggle to find time for relaxation and leisure activities?', 'Is your hostel or home environment causing you difficulties?', 'Do you lack confidence in your academic performance?', 'Do you lack confidence in your choice of academic subjects?', 'Academic and extracurricular activities conflicting for you?', 'Do you attend classes regularly?', 'Have you gained/lost weight?', 'Which type of stress do you primarily experience?']
#
# Numeric columns:
# ['Gender', 'Age', 'Have you recently experienced stress in your life?', 'Have you noticed a rapid heartbeat or palpitations?', 'Have you been dealing with anxiety or tension recently?', 'Do you face any sleep problems or difficulties falling asleep?', 'Have you been dealing with anxiety or tension recently?.1', 'Have you been getting headaches more often than usual?', 'Do you get irritated easily?', 'Do you have trouble concentrating on your academic tasks?', 'Have you been feeling sadness or low mood?', 'Have you been experiencing any illness or health issues?', 'Do you often feel lonely or isolated?', 'Do you feel overwhelmed with your academic workload?', 'Are you in competition with your peers, and does it affect you?', 'Do you find that your relationship often causes you stress?', 'Are you facing any difficulties with your professors or instructors?', 'Is your working environment unpleasant or stressful?', 'Do you struggle to find time for relaxation and leisure activities?', 'Is your hostel or home environment causing you difficulties?', 'Do you lack confidence in your academic performance?', 'Do you lack confidence in your choice of academic subjects?', 'Academic and extracurricular activities conflicting for you?', 'Do you attend classes regularly?', 'Have you gained/lost weight?']
#
# Categorical columns:
# ['Which type of stress do you primarily experience?']
#
# Meaningful numeric columns (excluding IDs, gender, etc.):
# ['Age', 'Have you recently experienced stress in your life?', 'Have you been dealing with anxiety or tension recently?', 'Do you face any sleep problems or difficulties falling asleep?', 'Have you been dealing with anxiety or tension recently?.1', 'Have you been getting headaches more often than usual?', 'Do you get irritated easily?', 'Do you have trouble concentrating on your academic tasks?', 'Have you been feeling sadness or low mood?', 'Have you been experiencing any illness or health issues?', 'Do you often feel lonely or isolated?', 'Do you feel overwhelmed with your academic workload?', 'Are you in competition with your peers, and does it affect you?', 'Do you find that your relationship often causes you stress?', 'Are you facing any difficulties with your professors or instructors?', 'Is your working environment unpleasant or stressful?', 'Do you struggle to find time for relaxation and leisure activities?', 'Is your hostel or home environment causing you difficulties?', 'Academic and extracurricular activities conflicting for you?', 'Do you attend classes regularly?', 'Have you gained/lost weight?']
#
# Working with numeric column: Age
#
# Original values:
#    Age
# 0   20
# 1   20
# 2   20
# 3   20
# 4   20
#
# Doubled values of Age:
#    Age  doubled_values
# 0   20              40
# 1   20              40
# 2   20              40
# 3   20              40
# 4   20              40
#
# Values multiplied by 10:
#    Age  multiplied_by_10
# 0   20               200
# 1   20               200
# 2   20               200
# 3   20               200
# 4   20               200
#
# Sum of Age and Have you recently experienced stress in your life?:
#    Age  Have you recently experienced stress in your life?  column_sum
# 0   20                                                  3           23
# 1   20                                                  2           22
# 2   20                                                  5           25
# 3   20                                                  3           23
# 4   20                                                  3           23
